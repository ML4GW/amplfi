# %%
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
data = Table.read("/home/ethan.marx/mlpe/resnet-v3/0_ra_dec.dat", format="ascii")

# %%
plt.hist(data["ra"], bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 4.000e+00, 7.000e+00, 1.300e+01, 4.600e+01, 1.420e+02,
#         3.330e+02, 5.690e+02, 8.560e+02, 1.105e+03, 1.164e+03, 1.244e+03,
#         9.900e+02, 9.070e+02, 6.360e+02, 4.750e+02, 3.450e+02, 2.730e+02,
#         2.250e+02, 1.700e+02, 1.360e+02, 1.270e+02, 9.600e+01, 7.200e+01,
# ...

# %%
plt.hist(data["dec"] * 360 / (2 * np.pi))
# Out:
# (array([3.000e+01, 3.560e+02, 1.082e+03, 3.420e+03, 4.617e+03, 4.590e+02,
#         2.300e+01, 6.000e+00, 1.000e+00, 4.000e+00]),
#  array([-2.67990668,  6.24607071, 15.1720481 , 24.09802549, 33.02400289,
#         41.94998028, 50.87595767, 59.80193506, 68.72791246, 77.65388985,
#         86.57986724]),
#  <BarContainer object of 10 artists>)
